# %% [markdown]
# ##Importing Libraries and dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('/content/drive/MyDrive/datasets/employee_burnout_analysis-AI 2.xlsx')

# %%
df.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      2008-09-30  Female      Service
# 1      fffe3700360033003500      2008-11-30    Male      Service
# 2  fffe31003300320037003900      2008-03-10  Female      Product
# 3  fffe32003400380032003900      2008-11-03    Male      Service
# 4  fffe31003900340031003600      2008-07-24  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No            2                  3.0                   3.8
# 1                 Yes            1                  2.0                   5.0
# 2                 Yes            2                  NaN                   5.8
# 3                 Yes            1                  1.0                   2.6
# 4                  No            3                  7.0                   6.9
#
#    Burn Rate
# 0       0.16
# 1       0.36
# 2       0.49
# 3       0.20
# 4       0.52

# %%
df.describe()
# Out:
#                      Date of Joining   Designation  Resource Allocation  \
# count                          22750  22750.000000         21369.000000
# mean   2008-07-01 09:28:05.274725120      2.178725             4.481398
# min              2008-01-01 00:00:00      0.000000             1.000000
# 25%              2008-04-01 00:00:00      1.000000             3.000000
# 50%              2008-07-02 00:00:00      2.000000             4.000000
# 75%              2008-09-30 00:00:00      3.000000             6.000000
# max              2008-12-31 00:00:00      5.000000            10.000000
# std                              NaN      1.135145             2.047211
#
#        Mental Fatigue Score     Burn Rate
# count          20633.000000  21626.000000
# mean               5.728188      0.452005
# min                0.000000      0.000000
# 25%                4.600000      0.310000
# 50%                5.900000      0.450000
# 75%                7.100000      0.590000
# max               10.000000      1.000000
# std                1.920839      0.198226

# %%
df.shape
# Out:
# (22750, 9)

# %% [markdown]
# ##Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Employee ID                0
# Date of Joining            0
# Gender                     0
# Company Type               0
# WFH Setup Available        0
# Designation                0
# Resource Allocation     1381
# Mental Fatigue Score    2117
# Burn Rate               1124
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Date of Joining       22750 non-null  datetime64[ns]
#  2   Gender                22750 non-null  object
#  3   Company Type          22750 non-null  object
#  4   WFH Setup Available   22750 non-null  object
#  5   Designation           22750 non-null  int64
#  6   Resource Allocation   21369 non-null  float64
#  7   Mental Fatigue Score  20633 non-null  float64
#  8   Burn Rate             21626 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 1.6+ MB

# %%
df=df.dropna(subset=['Burn Rate'],axis=0).reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# Employee ID                0
# Date of Joining            0
# Gender                     0
# Company Type               0
# WFH Setup Available        0
# Designation                0
# Resource Allocation     1278
# Mental Fatigue Score    1945
# Burn Rate                  0
# dtype: int64

# %%
for col in ['Resource Allocation','Mental Fatigue Score']:
  df[col]=df[col].fillna(df[col].mean())

# %%
df.isnull().sum()
# Out:
# Employee ID             0
# Date of Joining         0
# Gender                  0
# Company Type            0
# WFH Setup Available     0
# Designation             0
# Resource Allocation     0
# Mental Fatigue Score    0
# Burn Rate               0
# dtype: int64

# %% [markdown]
# ##EDA

# %%
df=df.drop(['Date of Joining','Employee ID'],axis=1)
df.head()
# Out:
#    Gender Company Type WFH Setup Available  Designation  Resource Allocation  \
# 0  Female      Service                  No            2             3.000000
# 1    Male      Service                 Yes            1             2.000000
# 2  Female      Product                 Yes            2             4.483831
# 3    Male      Service                 Yes            1             1.000000
# 4  Female      Service                  No            3             7.000000
#
#    Mental Fatigue Score  Burn Rate
# 0                   3.8       0.16
# 1                   5.0       0.36
# 2                   5.8       0.49
# 3                   2.6       0.20
# 4                   6.9       0.52

# %%
df['Gender']=df['Gender'].replace({'Female':1,'Male':0})
df['Company Type']=df['Company Type'].replace({'Product':1,'Service':0})
df['WFH Setup Available']=df['WFH Setup Available'].replace({'Yes':1,'No':0})

df.head()
# Out:
# <ipython-input-13-40c5447e53dd>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender']=df['Gender'].replace({'Female':1,'Male':0})
# <ipython-input-13-40c5447e53dd>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Company Type']=df['Company Type'].replace({'Product':1,'Service':0})
# <ipython-input-13-40c5447e53dd>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['WFH Setup Available']=df['WFH Setup Available'].replace({'Yes':1,'No':0})
#    Gender  Company Type  WFH Setup Available  Designation  \
# 0       1             0                    0            2
# 1       0             0                    1            1
# 2       1             1                    1            2
# 3       0             0                    1            1
# 4       1             0                    0            3
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate
# 0             3.000000                   3.8       0.16
# 1             2.000000                   5.0       0.36
# 2             4.483831                   5.8       0.49
# 3             1.000000                   2.6       0.20
# 4             7.000000                   6.9       0.52

# %%
df.dtypes
# Out:
# Gender                    int64
# Company Type              int64
# WFH Setup Available       int64
# Designation               int64
# Resource Allocation     float64
# Mental Fatigue Score    float64
# Burn Rate               float64
# dtype: object

# %%
df.shape
# Out:
# (21626, 7)

# %% [markdown]
# ##Importing Libraries for Prediction

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %% [markdown]
# ##Test Train Model

# %%
Y=df['Burn Rate']
X=df.drop('Burn Rate',axis=1)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=0,shuffle=False)

# %% [markdown]
# ##Model Selection

# %%
scaler=StandardScaler()

# %% [markdown]
# ###Linear Regression

# %%
lr=LinearRegression()
pipe=make_pipeline(scaler,lr)

pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
Y_pred=pipe.predict(X_test)

# %%
print("MSE of Linear regression is: ",mean_squared_error(Y_test,Y_pred))
print("RMSE of Linear regression is: ",np.sqrt(mean_squared_error(Y_test,Y_pred)))
print("Mean Absolute Error of Linear Regression is: ",mean_absolute_error(Y_test,Y_pred))
print()
print("R^2 Score of Linear regression is: ",r2_score(Y_test,Y_pred))
# Out:
# MSE of Linear regression is:  0.00494959970994304
# RMSE of Linear regression is:  0.07035339160227487
# Mean Absolute Error of Linear Regression is:  0.05362127161425442
#
# R^2 Score of Linear regression is:  0.8718297494172389

# %% [markdown]
# ###Ridge Regression

# %%
ridge=Ridge()
pipe=make_pipeline(scaler,ridge)
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
Y_pred_ridge=pipe.predict(X_test)

# %%
print("MSE of Ridge regression is: ",mean_squared_error(Y_test,Y_pred_ridge))
print("RMSE of Ridge regression is: ",np.sqrt(mean_squared_error(Y_test,Y_pred_ridge)))
print("Mean Absolute Error of Ridge Regression is: ",mean_absolute_error(Y_test,Y_pred_ridge))
print()
print("R^2 Score of Ridge regression is: ",r2_score(Y_test,Y_pred_ridge))
# Out:
# MSE of Ridge regression is:  0.00494959608757698
# RMSE of Ridge regression is:  0.07035336585819459
# Mean Absolute Error of Ridge Regression is:  0.05362137367530168
#
# R^2 Score of Ridge regression is:  0.871829843218676

# %% [markdown]
# ###K-Nearest Neighbors (KNN) Regression

# %%
knn_reg=KNeighborsRegressor(n_neighbors=5)
pipe=make_pipeline(scaler,knn_reg)
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('kneighborsregressor', KNeighborsRegressor())])

# %%
Y_pred_knn=pipe.predict(X_test)

# %%
print("MSE of KNN regression is: ",mean_squared_error(Y_test,Y_pred_knn))
print("RMSE of KNN regression is: ",np.sqrt(mean_squared_error(Y_test,Y_pred_knn)))
print("Mean Absolute Error of KNN Regression is: ",mean_absolute_error(Y_test,Y_pred_knn))
print()
print("R^2 Score of KNN regression is: ",r2_score(Y_test,Y_pred_knn))
# Out:
# MSE of KNN regression is:  0.004181391529498798
# RMSE of KNN regression is:  0.06466368014193746
# Mean Absolute Error of KNN Regression is:  0.05036286295542815
#
# R^2 Score of KNN regression is:  0.8917225570698397
